# %%
import csv
import networkx as nx
import numpy as np
from operator import itemgetter 
from scipy.stats import kendalltau
import pandas as pd
import math
from numpy import linalg as LA

G=nx.Graph()

f = open("ca-netscience.txt", "r")
edge1=[]
edge2=[]
nodelist=[]
for x in f:
  e1,e2=x.split()
  edge1.append(int(e1)-1)
  edge2.append(int(e2)-1)
  for i in (int(e1)-1,int(e2)-1):
      if i not in nodelist:
          nodelist.append(i)
nodelist.sort()
t=0
nnodelist=[]
dic={}
for i in nodelist:
    dic[i]=t
    nnodelist.append(dic[i])
    t=t+1

nodelist=nnodelist
for  i in range(0, len(edge1)):
    G.add_edge(dic[edge1[i]], dic[edge2[i]])

nedge1=[]
nedge2=[]
for  i in range(0, len(edge1)):
   nedge1.append(dic[edge1[i]])
   nedge2.append(dic[edge2[i]])
   
edge1=nedge1
edge2=nedge2
        
n=len(nodelist)
d=[0]*n
for i in  range(0,n):
    d[i]=edge1.count(i)+edge2.count(i)

B=nx.betweenness_centrality(G)
    

nodes = []
values = []

for item in B.items():
    nodes.append(item[0]), values.append(item[1])
 
# printing keys and values separately

#print("befored sorted")
#print("values : ", values)
#print("Nodes : ", nodes)

values,nodes=zip(*sorted(zip(values,nodes)))
values,nodes=list(values),list(nodes)
values.reverse()
nodes.reverse()
#print("after sorted")
print("Values: ", values)
print("Nodes: ", nodes)
#print("Top-10 Values: ",values[:10])
print("Top-10 Nodes: ",nodes[:10])
    
    
# n=10
# x=[]
# BC=[]
# #print(len(G.nodes))
# for i in range(0,round(len(G.nodes())*0.75),n):
#     new_G=nx.Graph()
#     new_G = G.copy()
#     new_G.remove_nodes_from(nodes[:i])
#     #print(G.nodes)
#     #print("Gnodes",len(G.nodes))
#     #print("newGnodes",len(new_G.nodes))
#     x.append(i)
#     BC.append(nx.number_connected_components(new_G))
#     #print(i)
# print(x)
# print(BC)
# #print(len(nodes[:i]))

# df=pd.DataFrame(list(zip(x,BC)),columns=['No_of_Nodes_Removed','No_of_Connected_Components'])
# print(df)
# df.to_excel('US_BC_No_Connected_Components.xlsx','Sheet1')


# df1=pd.DataFrame(list(zip(values,nodes)),columns=['Values','Nodes'])
# print(df1)
# df1.to_excel('US_BC_VN.xlsx','Sheet1')
# Out:
# Values:  [0.39718418135681216, 0.34514711880253085, 0.28602004110719537, 0.27016272041057465, 0.2554278416347383, 0.25062807899754763, 0.23165391320171955, 0.22154874297229846, 0.17487795951990634, 0.17468615473040033, 0.1563961713504025, 0.1520563824733063, 0.14842752030043013, 0.12507309633746413, 0.09146071419938531, 0.08705598360770775, 0.07233473046454303, 0.0700036556166419, 0.0668686478981772, 0.06458243852541591, 0.055437328590038026, 0.04682609855023648, 0.046608563849943156, 0.046608563849943156, 0.045606586445013614, 0.045448457607945615, 0.042828738141152956, 0.04211420084572179, 0.04193559271729351, 0.041747949793926806, 0.0416286565711853, 0.04011655485556281, 0.04011655485556281, 0.03753773285014777, 0.0372230275350143, 0.03660196763645039, 0.0364475881717261, 0.0318192116221673, 0.02989000066739208, 0.026244509003129694, 0.026230474506336574, 0.026183692850359517, 0.02148330596606459, 0.02100964169929687, 0.020995607202503753, 0.020995607202503753, 0.02099560720250375
# ...

# %%
nx.diameter(G)
# Out:
# 11

# %%
#Finding Average degree and  Average clustering coefficient of a network
Degrees=[val for (node,val) in G.degree()]
# print(Nodes_list)
print("The degrees of invidual nodes are:",Degrees)
print("The number of nodes(elements) in the graph(list) are:",len(Degrees))
print("The sum of degrees of all nodes is: ",sum(Degrees))
Avg_Deg=sum(Degrees)/len(Degrees)
print("The Average degree of a network is :",Avg_Deg)
print("The Average Clusteringcoefficient of a network is :",nx.average_clustering(G))
# Out:
, 12, 7, 59, 6, 19, 17, 17, 2, 7, 9, 3, 8, 5, 24, 14, 11, 4, 6, 3, 5, 4, 4, 14, 8, 6, 28, 3, 7, 9, 5, 6, 4, 5, 7, 16, 6, 1, 17, 3, 9, 5, 5, 2, 1, 4, 7, 2, 11, 1, 2, 6, 1, 10, 3, 1, 4, 2, 7, 48, 2, 1, 8, 4, 2, 9, 2, 16, 2, 2, 2, 1, 1, 3, 6, 3, 8, 2, 7, 1, 1, 9, 4, 5, 3, 1, 7, 3, 1, 4, 2, 2, 19, 1, 5, 3, 2, 1, 3, 3, 2, 1, 1, 4, 2, 1, 2, 5, 4, 1, 2, 2, 4, 4, 3, 4, 2, 2, 3, 3, 9, 4, 7, 1, 3, 2, 2, 2, 2, 1, 3, 3, 3, 4, 1, 5, 2, 2, 12, 8, 3, 2, 11, 4, 5, 2, 2, 2, 2, 3, 4, 2, 14, 2, 11, 7,
# ...

# %%
import csv
import networkx as nx
import numpy as np
import pandas as pd
from operator import itemgetter 
from scipy.stats import kendalltau
G=nx.Graph()
import matplotlib.pyplot as plt
f = open("Toy_DS_C1.txt", "r")
edge1=[]
edge2=[]
nodelist=[]
for x in f:
  e1,e2=x.split()
  edge1.append(int(e1)-1)
  edge2.append(int(e2)-1)
  for i in (int(e1)-1,int(e2)-1):
      if i not in nodelist:
          nodelist.append(i)
nodelist.sort()
t=0
nnodelist=[]
dic={}
for i in nodelist:
    dic[i]=t
    nnodelist.append(dic[i])
    t=t+1

nodelist=nnodelist
for  i in range(0, len(edge1)):
    G.add_edge(dic[edge1[i]], dic[edge2[i]])
print("Density of Graph is:",nx.density(G))
deg=[val for node,val in G.degree()]
Min_deg=min(deg)
print("Min. degree of node is: ",Min_deg)
n=G.number_of_nodes()
print("Total Nodes:",G.number_of_nodes())
print(Min_deg/n)
print("Number of articulationpoint: ",len(list(nx.articulation_points(G))))
# Out:
# Density of Graph is: 0.023887775551102206
# Min. degree of node is:  1
# Total Nodes: 500
# 0.002
# Number of articulationpoint:  37

# %%
import csv
import networkx as nx
import numpy as np
import pandas as pd
from operator import itemgetter 
from scipy.stats import kendalltau
G=nx.Graph()
import matplotlib.pyplot as plt
f = open("FB_COMBINED.txt", "r")
edge1=[]
edge2=[]
nodelist=[]
for x in f:
  e1,e2=x.split()
  edge1.append(int(e1)-1)
  edge2.append(int(e2)-1)
  for i in (int(e1)-1,int(e2)-1):
      if i not in nodelist:
          nodelist.append(i)
nodelist.sort()
t=0
nnodelist=[]
dic={}
for i in nodelist:
    dic[i]=t
    nnodelist.append(dic[i])
    t=t+1

nodelist=nnodelist
for  i in range(0, len(edge1)):
    G.add_edge(dic[edge1[i]], dic[edge2[i]])



B=nx.betweenness_centrality(G)
    

nodes = []
values = []

for item in B.items():
    nodes.append(item[0]), values.append(item[1])
 
# printing keys and values separately

#print("befored sorted")
#print("values : ", values)
#print("Nodes : ", nodes)

values,nodes=zip(*sorted(zip(values,nodes)))
values,nodes=list(values),list(nodes)
values.reverse()
nodes.reverse()
#print("after sorted")
print("Values: ", values)
print("Nodes: ", nodes)
#print("Top-10 Values: ",values[:10])
print("Top-10 Nodes: ",nodes[:10])
Degrees=[val for (node,val) in G.degree()]
# print(Nodes_list)
print("The degrees of invidual nodes are:",Degrees)
print("The number of nodes(elements) in the graph(list) are:",len(Degrees))
print("The number of edges of the graph are: ",len(G.edges()))
print("The sum of degrees of all nodes is: ",sum(Degrees))
Avg_Deg=sum(Degrees)/len(Degrees)
print("The Average degree of a network is :",Avg_Deg)
# Out:
# Values:  [0.09030450891104706, 0.08606897492750398, 0.07955972621424112, 0.06383215312809332, 0.0355584801248368, 0.02906341111421677, 0.028923933749571227, 0.028350446050706166, 0.025244995325947636, 0.024594656853303306, 0.02432213697132316, 0.02417193630514057, 0.022631662156436885, 0.020948029143790195, 0.020793745965446263, 0.020677156946546264, 0.01842937721757757, 0.017937296679993758, 0.017710767678683743, 0.016969393383916374, 0.016275668402456745, 0.015986745262200636, 0.015812241071631605, 0.01386533888129965, 0.013579924459423843, 0.013522036617828803, 0.013198039539383494, 0.012541744242082369, 0.012071732919691672, 0.011128603515116494, 0.010956659368184749, 0.010943067024126627, 0.00876436120836656, 0.008009442962551643, 0.007927219240976117, 0.007532339355620251, 0.007459142930170488, 0.007220538847569173, 0.007122034763786718, 0.007024979201668336, 0.006889510371441543, 0.006782630894000311, 0.006617874422495259, 0.006478637510267799, 0.006463915904467594, 0.00626798
# ...
